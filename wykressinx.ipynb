# %% [markdown]
# <a href="https://colab.research.google.com/github/boguslaw-major/Data-Science/blob/master/wykressinx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(-3,3,0.1)
y=np.sin(x)

plt.plot(x,y)
plt.title("Wykres y=sinx")
plt.show()
