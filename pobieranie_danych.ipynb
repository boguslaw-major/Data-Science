# %% [markdown]
# <a href="https://colab.research.google.com/github/boguslaw-major/Data-Science/blob/master/pobieranie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
url= "https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?file=data/avia_par_pl.tsv.gz&unzip=true"
pd.read_csv(url,delimiter="\t")
# Out:
#               unit,tra_meas,airp_pr\time 2019Q3   ... 2004M01   2004
# 0         FLIGHT,CAF_PAS,PL_EPBY_BG_LBBG     70   ...       :      :
# 1         FLIGHT,CAF_PAS,PL_EPBY_DE_EDDF    184   ...       :      :
# 2         FLIGHT,CAF_PAS,PL_EPBY_DE_EDLV      :   ...       :      :
# 3         FLIGHT,CAF_PAS,PL_EPBY_ES_LEGE      :   ...       :      :
# 4         FLIGHT,CAF_PAS,PL_EPBY_IE_EIDW     60   ...       :      :
# ...                                  ...     ...  ...      ...    ...
# 1431  FLIGHT,CAF_PAS_DEP,PL_EPWA_FR_LFPG    582   ...     172   2509
# 1432  FLIGHT,CAF_PAS_DEP,PL_EPWA_GE_UGTB      :   ...       :      :
# 1433  FLIGHT,CAF_PAS_DEP,PL_EPWA_HU_LHBP    579   ...      58    905
# 1434  FLIGHT,CAF_PAS_DEP,PL_EPWA_IE_EIDW      :   ...       :      :
# 1435  FLIGHT,CAF_PAS_DEP,PL_EPWA_IL_LLBG    421   ...      NaN    NaN
#
# [1436 rows x 268 columns]
